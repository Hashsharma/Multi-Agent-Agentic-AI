# %%
# pip install pandas pyarrow
# pip install llama-index llama-index-embeddings-huggingface
# Out:
# Requirement already satisfied: pandas in /home/scientist-ubuntu/projects/all_venv_ubuntu/vvenv_extraction/lib/python3.10/site-packages (2.3.3)
# Collecting pyarrow
#   Using cached pyarrow-24.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (48.8 MB)
# Requirement already satisfied: pytz>=2020.1 in /home/scientist-ubuntu/projects/all_venv_ubuntu/vvenv_extraction/lib/python3.10/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/scientist-ubuntu/projects/all_venv_ubuntu/vvenv_extraction/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /home/scientist-ubuntu/projects/all_venv_ubuntu/vvenv_extraction/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: tzdata>=2022.7 in /home/scientist-ubuntu/projects/all_venv_ubuntu/vvenv_extraction/lib/python3.10/site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /home/scientist-ubuntu/projects/all_venv_ubuntu/vvenv_extraction/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-24.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_parquet("../../../resources/datasets/train-00000-of-00001.parquet", engine="pyarrow")

# %%
# from sentence_transformers import SentenceTransformer
# model_path = "/mnt/d/mr_document/all_models/bge-small-en-v1.5"
# # model = SentenceTransformer(model_path)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 1433.39it/s]
# BertModel LOAD REPORT from: /mnt/d/mr_document/all_models/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from llama_index.core import Document, VectorStoreIndex, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
model_path = "/mnt/d/mr_document/all_models/bge-small-en-v1.5"

# %%
embed_model = HuggingFaceEmbedding(model_name=model_path)
Settings.embed_model = embed_model

document = []
